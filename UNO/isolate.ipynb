# %%
# !pip install numpy -q
# !pip install matplotlib -q
# !pip install pillow -q
# !pip install pandas -q
# !pip install scikit-learn -q
# !pip install tqdm -q
# !pip install gdown -q

# %%
# Import main packages
# %reload_ext autoreload 
# %autoreload 2 

import os
import copy
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd ########

import core
import features
import presence
import template
import isolate

#from UNO import * ###
from pathlib import Path #######
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from typing import Optional, Callable
from sklearn.metrics import accuracy_score, f1_score
from sklearn.covariance import LedoitWolf


from utils.lab_03_utils import *
from isolate import *
# Out:
# isolate.py loaded

# %%
image1 = core.image(core.valid_nb(3))

image1.draw(500, 501, 1500, 2500, core.BLACK)
print(image1.show_info(core.IDX.ACTIVE_PLAYER))

image1.display(temporary=False) # not very fancy to print the whole array but still useful to return it
# Out:
# white background
# p4

# %%
image11 = image1.get(temporary=False)
print(image11[500, 500, 0], image11[500, 500, 1], image11[500, 500, 2])
# Out:
# 213 217 218

# %%
N,M,_ = image11.shape

mask = np.ones((N, M))

for n in range(N):
    for m in range(M):
        if np.mean(image11[n, m]) > 100:
            for i in range(3):
                mask[n, m] = 0

# %%
plt.imshow(mask)

# %%
seeds = [
        (500, 500),
    ]
# Add you additional arguments in the dictionary below
kwargs = {
    'thresh_r': 160,
    'thresh_g': 150,
    'thresh_b': 170,
}
print(image11.shape)
# Out:
# (2662, 4000, 3)

# %%
image12 = isolate.region_growing(seeds, image11, n_max = 2000, **kwargs)
plt.imshow(image12)

# %%
imx = core.image(12)
imx.display()

# %%
isolate.plot_pixel_profile(imx, [10, 400, 2000, 2500])

# %%
i = 1  # index à incrémenter
t = (1200, 300)
t = (*t[:i], t[i] + 1, *t[i:])

print(t)
# Out:
# (1200, 300, 301, 300)
